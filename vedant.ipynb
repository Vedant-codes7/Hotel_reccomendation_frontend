# %%
import pandas as pd 
df=pd.read_csv("DATASET.csv")
# Out:
#              hotel_name                                            address  \
# 0     Mumbai_Hotel_0103  Mahajan Tower, Mahajan Market, Sitabuldi, 4400...
# 1     Mumbai_Hotel_0436                                                NaN
# 2     Mumbai_Hotel_0271  Kas,Kas Bamnoli Road, near 10 min of kas plate...
# 3     Mumbai_Hotel_0107                                                NaN
# 4     Mumbai_Hotel_0072  130/2,Bangalore-Pune,Highway,Wakad, 411057 Pun...
# ...                 ...                                                ...
# 7930  Mumbai_Hotel_0233  Near Lilavati Hospital, Bandra Reclamation, Ba...
# 7931  Mumbai_Hotel_0394  Opp. Akashwani, Jalna Road Kailash Nagar Mondh...
# 7932  Mumbai_Hotel_0501  Kailash Puram, Near Sakinaka Metro Station Gat...
# 7933  Mumbai_Hotel_0251  New Mangalwar Peth,Near Sinchan Bhavan, 411011...
# 7934  Mumbai_Hotel_0521  Old Khandala Road, Rustic Island, 410302 Lonav...
#
# ...
